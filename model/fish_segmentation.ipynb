# %%
#Setup!
# !pip3 install torch torchvision torchaudio
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
from fastbook import *
# !pip install kaggle
# %matplotlib inline
from fastai.vision.all import *
from pathlib import Path
from fastai.callback.hook import *

# %%
#Mount the drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# Unzip all data in a local env
# !unzip gdrive/My\ Drive/Colab_Dataset/Segmentation.zip

# %%
# Dataset
path = Path('/content/Segmentation')
path.ls()
# Out:
# (#6) [Path('/content/Segmentation/segmentation.csv'),Path('/content/Segmentation/masks'),Path('/content/Segmentation/images'),Path('/content/Segmentation/val.csv'),Path('/content/Segmentation/test.csv'),Path('/content/Segmentation/train.csv')]

# %%
img_path = path/'images/valid'; img_path.ls()
# Out:
# (#310) [Path('/content/Segmentation/images/valid/7623_F2_f000120.jpg'),Path('/content/Segmentation/images/valid/7482_F3_f000020.jpg'),Path('/content/Segmentation/images/valid/7482_F2_f000320.jpg'),Path('/content/Segmentation/images/valid/9894_Amniataba_caudivittatus_f000010.jpg'),Path('/content/Segmentation/images/valid/9866_acanthopagrus_and_caranx_f000200.jpg'),Path('/content/Segmentation/images/valid/9852_Lutjanus_russellii_EJP_f000010.jpg'),Path('/content/Segmentation/images/valid/9866_acanthopagrus_palmaris_f000440.jpg'),Path('/content/Segmentation/images/valid/9866_acanthopagrus_and_caranx_f000170.jpg'),Path('/content/Segmentation/images/valid/9898_Acanthopagrus_palmaris_f000010.jpg'),Path('/content/Segmentation/images/valid/9866_acanthopagrus_and_caranx_f000290.jpg')...]

# %%
labels = path/'masks/valid1'; labels.ls()
# Out:
# (#310) [Path('/content/Segmentation/masks/valid1/7623_F2_f000120.jpg'),Path('/content/Segmentation/masks/valid1/7482_F3_f000020.jpg'),Path('/content/Segmentation/masks/valid1/7482_F2_f000320.jpg'),Path('/content/Segmentation/masks/valid1/9894_Amniataba_caudivittatus_f000010.jpg'),Path('/content/Segmentation/masks/valid1/9866_acanthopagrus_and_caranx_f000200.jpg'),Path('/content/Segmentation/masks/valid1/9852_Lutjanus_russellii_EJP_f000010.jpg'),Path('/content/Segmentation/masks/valid1/9866_acanthopagrus_palmaris_f000440.jpg'),Path('/content/Segmentation/masks/valid1/9866_acanthopagrus_and_caranx_f000170.jpg'),Path('/content/Segmentation/masks/valid1/9898_Acanthopagrus_palmaris_f000010.jpg'),Path('/content/Segmentation/masks/valid1/9866_acanthopagrus_and_caranx_f000290.jpg')...]

# %% [markdown]
# Gotta use PILImage.create() and PILMaks.create() :) Stop wasting your time with open_image and open_mask

# %%
fnames = get_image_files(img_path)
img_f = fnames[0]
img = PILImage.create(img_f)
img.show(figsize=(5,5))

# %%
mask = PILMask.create(img_f)
mask.show(figsize=(5,5))

# %%
fnames = get_image_files(img_path)
labels_list = ['_'.join(x.name.split('_')) for x in fnames]
code_list = ['_'.join(x.name.split('_')[1:-1]) for x in fnames]

# %%
#code_list # Used to get the codes

# %%
#labels_list # To get an array of all files in img_path to create a txt file

# %%
codes = array(code_list, dtype='<U17')

# %%
codes
# Out:
# array(['F2', 'F3', 'F2', 'Amniataba_caudivi', 'acanthopagrus_and', 'Lutjanus_russelli', 'acanthopagrus_pal', 'acanthopagrus_and', 'Acanthopagrus_pal', 'acanthopagrus_and', 'Epinephelus', 'F2',
#        'acanthopagrus_pal', 'Lutjanus_russelli', 'F6', 'Lutjanus_russelli', 'Lutjanus_argentim', 'Acanthopagrus_pal', 'F2', 'F6', 'F3', 'Lutjanus_argentim', 'acanthopagrus_pal', 'acanthopagrus_pal',
#        'Acanthopagrus_pal', 'F4', 'Lutjanus_russelli', 'Acanthopagrus_pal', 'F2', 'F3', 'F2', 'acanthopagrus_and', 'F6', 'F2', 'F2', 'F3', 'F2', 'F2', 'F3', 'Acanthopagrus_pal', 'Epinephelus',
#        'Epinephelus', 'F6', 'F3', 'F3', 'F2', 'F2', 'Acanthopagrus_pal', 'Acanthopagrus_pal', 'F4', 'F3', 'acanthopagrus_pal', 'Lutjanus_a_testcl', 'Epinephelus', 'acanthopagrus_and', 'F2',
#        'Acanthopagrus_pal', 'F6', 'Acanthopagrus_pal', 'acanthopagrus_pal', 'F2', 'lutjanus_johnii', 'F6', 'F2', 'F3', 'acanthopagrus_pal', 'F3', 'acanthopagrus_and', 'Lutjanus_argentim', 'F2', 'F3',
#        'acanthopagrus_and', 'acanthopagrus_and', 'Acanthopagrus_pal', 'F6', 'Gerres', 'F3', 'F6', 'F2', 'F6', 'F6', 'Acanthopagrus_pal', 'F2', 'F3', 'Gerres', 'F2', 'F4', 'Caranx', 'F2',
#        'Lutjanus_russelli', 'F2', 'F2', 'Lutjanus_a_testcl', 'Gerres', 'gerres', 'acanthopagrus_pal', 'acanthopagrus_and', 'F3', 'F4', 'F2', 'Chaetodon_vagabun', 'F2', 'F2', 'acanthopagrus_and',
#        'Acanthopagrus_pal', 'F2', 'Epinephelus', 'F3', 'F3', 'acanthopagrus_and', 'Acanthopagrus_pal', 'F2', 'Acanthopagrus_pal', 'F2', 'F2', 'acanthopagrus_and', 'Acanthopagrus_pal',
#        'Acanthopagrus_pal', 'gerres_2', 'Acanthopagrus_pal', 'acanthopagrus_pal', 'Acanthopagrus_pal', 'F2', 'F2', 'Gerres', 'F2', 'F6', 'Acanthopagrus_pal', 'Caranx', 'Lutjanus_argentim',
#        'acanthopagrus_pal', 'F2', 'Lutjanus_argentim', 'F6', 'F2', 'acanthopagrus_pal', 'F2', 'F3', 'Gerres', 'Acanthopagrus_pal', 'acanthopagrus_pal', 'F2', 'acanthopagrus_pal', 'F2',
#        'Lutjanus_a_testcl', 'F2', 'acanthopagrus_pal', 'Epinephelus', 'acanthopagrus_and', 'F2', 'acanthopagrus_pal', 'Acanthopagrus_pal', 'Acanthopagrus_pal', 'F2', 'F3', 'F2', 'F6',
#        'acanthopagrus_pal', 'Chaetodon_vagabun', 'acanthopagrus_pal', 'gerres_2', 'Amniataba_caudivi', 'F3', 'F3', 'acanthopagrus_and', 'acanthopagrus_and', 'F6', 'F2', 'acanthopagrus_pal', 'F3',
#        'Acanthopagrus_pal', 'gerres', 'F2', 'Gerres', 'Gerres', 'Epinephelus', 'F2', 'Chaetodon_vagabun', 'F3', 'acanthopagrus_pal', 'Gerres', 'F2', 'acanthopagrus_pal', 'F2', 'F3',
#        'acanthopagrus_pal', 'Lutjanus_argentim', 'acanthopagrus_pal', 'Acanthopagrus_pal', 'acanthopagrus_pal', 'acanthopagrus_pal', 'F4', 'Epinephelus', 'acanthopagrus_and', 'acanthopagrus_and',
#        'F2', 'acanthopagrus_pal', 'F6', 'Amniataba_caudivi', 'F2', 'lutjanus_johnii', 'F6', 'F6', 'acanthopagrus_and', 'F2', 'acanthopagrus_and', 'F1', 'Caranx', 'Gerres', 'acanthopagrus_pal', 'F2',
#        'acanthopagrus_pal', 'gerres_2', 'Amniataba_caudivi', 'Epinephelus', 'Chaetodon_vagabun', 'F2', 'F2', 'F2', 'acanthopagrus_pal', 'Acanthopagrus_pal', 'Gerres', 'F2', 'Gerres',
#        'Acanthopagrus_pal', 'F2', 'acanthopagrus_pal', 'Lutjanus_argentim', 'Acanthopagrus_pal', 'acanthopagrus_pal', 'acanthopagrus_pal', 'acanthopagrus_pal', 'Acanthopagrus_pal', 'Epinephelus',
#        'F3', 'F2', 'lutjanus_johnii', 'gerres', 'Acanthopagrus_pal', 'acanthopagrus_pal', 'F2', 'F6', 'Acanthopagrus_pal', 'acanthopagrus_pal', 'Lutjanus_argentim', 'F2', 'F2', 'Lutjanus_a_testcl',
#        'Acanthopagrus_pal', 'Epinephelus', 'F2', 'F2', 'acanthopagrus_pal', 'acanthopagrus_and', 'F2', 'Acanthopagrus_pal', 'acanthopagrus_and', 'F2', 'Acanthopagrus_pal', 'F3', 'F2', 'F2',
#        'Acanthopagrus_pal', 'Acanthopagrus_pal', 'gerres_2', 'F2', 'acanthopagrus_pal', 'gerres', 'Acanthopagrus_pal', 'F2', 'Chaetodon_vagabun', 'Acanthopagrus_pal', 'F2', 'acanthopagrus_pal',
#        'Acanthopagrus_pal', 'acanthopagrus_and', 'acanthopagrus_pal', 'Epinephelus', 'F6', 'Gerres', 'F2', 'F2', 'acanthopagrus_pal', 'F6', 'acanthopagrus_pal', 'acanthopagrus_pal',
#        'acanthopagrus_and', 'Gerres', 'Acanthopagrus_pal', 'F2', 'Acanthopagrus_pal', 'acanthopagrus_and', 'acanthopagrus_pal', 'F2', 'Acanthopagrus_pal', 'F2', 'F2', 'F2', 'acanthopagrus_and',
#        'acanthopagrus_and', 'F2', 'Acanthopagrus_pal', 'F2', 'Lutjanus_argentim', 'F2', 'acanthopagrus_and', 'F2', 'Caranx', 'acanthopagrus_and', 'F4'], dtype='<U17')

# %%
get_msk = lambda o: labels/f'{o.stem}{o.suffix}'

# %%
def FileSplitter(fname):
    "Split `items` depending on the value of `mask`."
    valid = Path(fname).read_text().split('\n') 
    def _func(x): return x.name in valid
    def _inner(o, **kwargs): return FuncSplitter(_func)(o)
    return _inner

# %% [markdown]
# ## Datablock

# %%
sz = mask.shape; sz
# Out:
# (1080, 1920)

# %%
half = tuple(int(x/3) for x in sz); half
# Out:
# (360, 640)

# %%
camvid = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=get_image_files,
                   splitter=FileSplitter('/content/valid.txt'),
                   get_y=get_msk,
                   batch_tfms=[*aug_transforms(size=half), Normalize.from_stats(*imagenet_stats)])

# %%
dls = camvid.dataloaders(img_path, bs=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:1142: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   ret = func(*args, **kwargs)

# %%
dls.train_ds.items[:310]

# %%
dls.show_batch(max_n=4, vmin=1, vmax=30, figsize=(14,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:1142: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   ret = func(*args, **kwargs)

# %% [markdown]
# ### Training

# %%
opt = ranger
dls.vocab = codes

# %%
name2id = {v:k for k,v in enumerate(codes)} 
name2id
# Out:
# {'Acanthopagrus_pal': 301,
#  'Amniataba_caudivi': 213,
#  'Caranx': 307,
#  'Chaetodon_vagabun': 270,
#  'Epinephelus': 277,
#  'F1': 206,
#  'F2': 306,
#  'F3': 259,
#  'F4': 309,
#  'F6': 283,
#  'Gerres': 287,
#  'Lutjanus_a_testcl': 247,
#  'Lutjanus_argentim': 303,
#  'Lutjanus_russelli': 89,
#  'acanthopagrus_and': 308,
#  'acanthopagrus_pal': 292,
#  'gerres': 267,
#  'gerres_2': 264,
#  'lutjanus_johnii': 236}

# %% [markdown]
# In most dataset there is a label called Void which we want to filter out. However since some part of the dataset is selfmade, I did not have to do it.

# %%
#void_code = name2id['F6']

# %%
#def acc_camvid(inp, targ):
#  targ = targ.squeeze(1)
#  mask = targ != void_code
#  return (inp.argmax(dim=1)[mask]==targ[mask]).float().mean()

# %%
learn = unet_learner(dls, resnet34, metrics=error_rate, self_attention=True, act_cls=Mish, opt_func=opt)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:1142: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   ret = func(*args, **kwargs)

# %%
lr_min,lr_steep = learn.lr_find(suggest_funcs=(minimum, steep))
print(f"Minimum/10: {lr_min:.2e}, steepest point: {lr_steep:.2e}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:1142: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   ret = func(*args, **kwargs)
# Minimum/10: 1.58e-03, steepest point: 1.58e-04

# %%
learn.lr_find()

# %%
learn.fit_flat_cos(3, slice(1.10e-03))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 01:13<02:26]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.130605</td>
#       <td>None</td>
#       <td>None</td>
#       <td>01:13</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='9' class='' max='155' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.81% [9/155 00:04<01:15 0.1187]
#     </div>
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:1142: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.7/dist-packages/fastprogress/fastprogress.py:74: UserWarning: Your generator is empty.
#   warn("Your generator is empty.")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-5bf3b5fa2d7e> in <module>()
# ----> 1 learn.fit_flat_cos(3, slice(1.10e-03))
#
# /usr/local/lib/python3.7/dist-packages/fastai/callback/schedule.py in fit_flat_cos(self, n_epoch, lr, div_final, pct_start, wd, cbs, reset_opt)
#     137     lr = np.array([h['lr'] for h in self.opt.hypers])
#     138     scheds = {'lr': combined_cos(pct_start, lr, lr, lr/div_final)}
# --> 139     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd)
#     140
#     141 # Cell
#
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     219             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     220             self.n_epoch = n_epoch
# --> 221             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     222
#     223     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py in _do_fit(self)
#     210         for epoch in range(self.n_epoch):
#     211             self.epoch=epoch
# --> 212             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     213
#     214     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False):
#
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py in _do_epoch(self)
#     204
#     205     def _do_epoch(self):
# --> 206         self._do_epoch_train()
#     207         self._do_epoch_validate()
#     208
#
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py in _do_epoch_train(self)
#     196     def _do_epoch_train(self):
#     197         self.dl = self.dls.train
# --> 198         self._with_events(self.all_batches, 'train', CancelTrainException)
#     199
#     200     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py in all_batches(self)
#     167     def all_batches(self):
#     168         self.n_iter = len(self.dl)
# --> 169         for o in enumerate(self.dl): self.one_batch(*o)
#     170
#     171     def _do_one_batch(self):
#
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py in one_batch(self, i, b)
#     192         b = self._set_device(b)
#     193         self._split(b)
# --> 194         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     195
#     196     def _do_epoch_train(self):
#
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py in _do_one_batch(self)
#     178         if not self.training or not len(self.yb): return
#     179         self('before_backward')
# --> 180         self.loss_grad.backward()
#     181         self._with_events(self.opt.step, 'step', CancelStepException)
#     182         self.opt.zero_grad()
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     360                 retain_graph=retain_graph,
#     361                 create_graph=create_graph,
# --> 362                 inputs=inputs)
#     363         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     364
#
# /usr/local/lib/python3.7/dist-packages/torch/overrides.py in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1392         # Use `public_api` instead of `implementation` so __torch_function__
#    1393         # implementations can do equality/identity comparisons.
# -> 1394         result = torch_func_method(public_api, types, args, kwargs)
#    1395
#    1396         if result is not NotImplemented:
#
# /usr/local/lib/python3.7/dist-packages/fastai/torch_core.py in __torch_function__(self, func, types, args, kwargs)
#     339         convert=False
#     340         if _torch_handled(args, self._opt, func): convert,types = type(self),(torch.Tensor,)
# --> 341         res = super().__torch_function__(func, types, args=args, kwargs=kwargs)
#     342         if convert: res = convert(res)
#     343         if isinstance(res, TensorBase): res.set_meta(self, as_copy=True)
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in __torch_function__(cls, func, types, args, kwargs)
#    1140
#    1141         with _C.DisableTorchFunction():
# -> 1142             ret = func(*args, **kwargs)
#    1143             if func in get_default_nowrap_functions():
#    1144                 return ret
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     361                 create_graph=create_graph,
#     362                 inputs=inputs)
# --> 363         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     364
#     365     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#     176
#     177 def grad(
#
# KeyboardInterrupt:

# %%
learn.save('model_1')
# Out:
# Path('models/model_1.pth')

# %%
learn.show_results(max_n=4, figsize=(18,8))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-4c88d99a5d7d> in <module>()
# ----> 1 learn.show_results(max_n=4, figsize=(18,8))
#
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py in show_results(self, ds_idx, dl, max_n, shuffle, **kwargs)
#     277     def show_results(self, ds_idx=1, dl=None, max_n=9, shuffle=True, **kwargs):
#     278         if dl is None: dl = self.dls[ds_idx].new(shuffle=shuffle)
# --> 279         b = dl.one_batch()
#     280         _,_,preds = self.get_preds(dl=[b], with_decoded=True)
#     281         dl.show_results(b, preds, max_n=max_n, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/fastai/data/load.py in one_batch(self)
#     167     def to(self, device): self.device = device
#     168     def one_batch(self):
# --> 169         if self.n is not None and len(self)==0: raise ValueError(f'This DataLoader does not contain any batches')
#     170         with self.fake_l.no_multiproc(): res = first(self)
#     171         if hasattr(self, 'it'): delattr(self, 'it')
#
# ValueError: This DataLoader does not contain any batches
